# %%
import pandas as pd

# %%
df = pd.read_csv('Salary.csv')

# %%
df.head(
    
)
# Out:
#    YearsExperience  Salary
# 0              1.1   39343
# 1              1.3   46205
# 2              1.5   37731
# 3              2.0   43525
# 4              2.2   39891

# %%
df.shape
# Out:
# (30, 2)

# %%
X = df[['YearsExperience']]

# %%
X
# Out:
# 0      1.1
# 1      1.3
# 2      1.5
# 3      2.0
# 4      2.2
# 5      2.9
# 6      3.0
# 7      3.2
# 8      3.2
# 9      3.7
# 10     3.9
# 11     4.0
# 12     4.0
# 13     4.1
# 14     4.5
# 15     4.9
# 16     5.1
# 17     5.3
# 18     5.9
# 19     6.0
# 20     6.8
# 21     7.1
# 22     7.9
# 23     8.2
# 24     8.7
# 25     9.0
# 26     9.5
# 27     9.6
# 28    10.3
# 29    10.5
# Name: YearsExperience, dtype: float64

# %%
Y = df['Salary']

# %%
# !pip install scikit-learn
from sklearn.model_selection import train_test_split
# Out:
# Requirement already satisfied: scikit-learn in /home/nibiru/.conda/envs/ml/lib/python3.11/site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in /home/nibiru/.conda/envs/ml/lib/python3.11/site-packages (from scikit-learn) (2.4.3)
# Requirement already satisfied: scipy>=1.10.0 in /home/nibiru/.conda/envs/ml/lib/python3.11/site-packages (from scikit-learn) (1.17.1)
# Requirement already satisfied: joblib>=1.3.0 in /home/nibiru/.conda/envs/ml/lib/python3.11/site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /home/nibiru/.conda/envs/ml/lib/python3.11/site-packages (from scikit-learn) (3.6.0)

# %%
X_train , X_test, Y_train, Y_test = train_test_split(X,Y, test_size = 0.2, random_state = 42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred=model.predict(X_test)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test, model.predict(X_test))
# Out:
# 0.9024461774180497

# %%
import matplotlib.pyplot as plt
plt.scatter(X_test, Y_test, color = 'red')
plt.plot(X_test, Y_pred, color='red', label='AI Prediction Line')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend()
plt.show()

# %%
import joblib
joblib.dump(model, 'salary_predictor_model.pkl')
# Out:
# ['salary_predictor_model.pkl']

# %%
pip install fastapi
